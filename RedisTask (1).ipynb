# %%
# !pip install redis
import redis
client = redis.Redis(host = '43.251.253.107', port=1500,db=2)
client3 = redis.Redis(host = '43.251.253.107', port=1500,db=3)



client.ping()
# Out:
# ...
#      |████████████████████████████████| 226 kB 23.6 MB/s
# ...
# True

# %%
link=client.srandmember("all_domains")
link = link.decode("utf-8")
client.srem("all_domains",link)
print(link)

# %%
link_output = client3.smembers('urls')

# %%
print(link_output)

for item in link_output:
  url = item.decode("utf-8")
  client.sadd('elo',url)
# Out:
# {b'https://www.exportleftovers.com/pages/28838', b'https://www.exportleftovers.com/products/f-f-womens-el-monte-straight-fit-denim', b'https://www.exportleftovers.com/products/poler-mens-avila-contrast-colour-raglan-sleeve-polo-shirt', b'https://www.exportleftovers.com/products/poler-kids-always-happy-printed-short-sleeve-tee-shirt', b'https://www.exportleftovers.com/pages/3452', b'https://www.exportleftovers.com/pages/29128', b'https://www.exportleftovers.com/pages/8635', b'https://www.exportleftovers.com/pages/18041', b'https://www.exportleftovers.com/products/mens-miraah-prestonfield-sneaker-shoes', b'https://www.exportleftovers.com/pages/29802', b'https://www.exportleftovers.com/pages/5508-g', b'https://www.exportleftovers.com/products/big-boss-mens-bangor-classic-regular-fit-dress-shirt', b'https://www.exportleftovers.com/pages/20597', b'https://www.exportleftovers.com/products/mens-manado-genuine-leather-card-holder', b'https://www.exportleftovers.com/products/polo-republica-in
# ...

# %%
# import requests
# import json
# links = ['https://www.exportleftovers.com/products/instantly-whitening-magic-facial-mask','https://www.exportleftovers.com/products/pbx-professional-beauty-eyebrow-mascara']
# for item in links:
#   try:
#     item = item+'.json'
#     if '/collections/' in item:
#       response = requests.get(item)
#       json_data = json.loads(response.text)
#       print(json_data)
#       jsonString = json.dumps(json_data)
#       jsonFile = open("data34.jsonl", "a")
#       jsonFile.write(jsonString)
#       jsonFile.close()
#   except:
#     print("something wrong in",item)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import json
def dump_jsonl(data, output_path, append=False):
    """
    Write list of objects to a JSON lines file.
    """
    mode = 'a+' if append else 'w'
    with open(output_path, mode, encoding='utf-8') as f:
        for line in data:
            json_record = json.dumps(line, ensure_ascii=False)
            f.write(json_record + '\n')
    print('Wrote {} records to {}'.format(len(data), output_path))

# %%
import requests
import json

while 1 == 1:
  try:
    #random get url from db2
    link=client.srandmember("elo")
    #put a url in variable and decode
    link = link.decode("utf-8")
    #check either /products/ available or not
    #remove the url from redis
    client.srem("elo",link)
    if '/products/' or '/collections/' in link:
        link = link+'.json'
        #then pass the url to request
        response = requests.get(link)
        json_data = json.loads(response.text)
        # print(json_data)
        #add to jsonl file
        dump_jsonl([json_data], '/content/drive/MyDrive/Cognilium/data1elo.jsonl', append=True)
  except Exception as e:  
    print(e)

# %%
# import requests
# import json
# links = ['https://www.exportleftovers.com/products/instantly-whitening-magic-facial-mask','https://www.exportleftovers.com/products/pbx-professional-beauty-eyebrow-mascara']
# for item in links:
#   try:
#     item = item+'.json'
#     if '/products/' in item:
#       response = requests.get(item)
#       json_data = json.loads(response.text)
#       print(json_data)
#       jsonString = json.dumps(json_data)
#       jsonFile = open("data34.jsonl", "a")
#       jsonFile.write(jsonString)
#       jsonFile.close()
#   except:
#     print("something wrong in",item)

# %%
def load_jsonl(input_path) -> list:
    """
    Read list of objects from a JSON lines file.
    """
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.rstrip('\n|\r')))
    print('Loaded {} records from {}'.format(len(data), input_path))
    return data

# %%
import json
webpage_data = load_jsonl('/content/drive/MyDrive/Cognilium/data1brandspopper.jsonl')
# for d in webpage_data:
for item in webpage_data:
  with open('/content/drive/MyDrive/Cognilium/brandspopperProductType.txt', 'a') as f:
    try:
      f.write(str(item['product']['product_type']))
      f.write("\n")
      f.close()
    except:
      pass
# Out:
# Loaded 895 records from /content/drive/MyDrive/Cognilium/data1brandspopper.jsonl

# %%
# !pip install redis
import json
import redis
import os
path = "Enter Folder Path"
os.chdir(path)

def read_text_file(file_path):
	with open(file_path, 'r') as f:
		print(f.read())

for file in os.listdir():
	if file.endswith(".jsonl"):
		read_text_file(file)





client = redis.Redis(host = '43.251.253.107', port=1500,db=1)
def load_jsonl(input_path) -> list:
    """
    Read list of objects from a JSON lines file.
    """
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.rstrip('\n|\r')))
    print('Loaded {} records from {}'.format(len(data), input_path))
    return data


webpage_data = load_jsonl('/content/drive/MyDrive/Cognilium/data1elo.jsonl')
# for d in webpage_data:
for item in webpage_data:
    try:
      client.sadd("allProductTypes",item['product']['product_type'])
    except Exception as e:
        print(e)     
    try:
        client.sadd("allProductTypes",item['collection']['handle'])
    except Exception as e:
       print(e)

# %%
{"collection": {"id": 161586610256, "title": "Boys Belts", "handle": "boys-belts", "description": "", "published_at": "2020-04-21T12:16:36+05:00", "updated_at": "2021-09-14T01:50:25+05:00", "image": null, "products_count": 8}}
{"product": {"id": 7155381043391, "title": "Mom Fit Jeans", "body_html": "<p data-mce-fragment=\"1\">(model-data)</p>\n<p data-mce-fragment=\"1\">The model is wearing size: 26; Model height:<span data-mce-fragment=\"1\"> 5.3</span>ft /160cm</p>\n<p data-mce-fragment=\"1\">(model-data-end)</p>\n<p data-mce-fragment=\"1\">(main-data)</p>\n<p data-mce-fragment=\"1\"><strong data-mce-fragment=\"1\">Fit:</strong><span data-mce-fragment=\"1\"> </span>Mom</p>\n<p data-mce-fragment=\"1\"><strong data-mce-fragment=\"1\">Composition &amp; Care:</strong></p>\n<ul>\n<li>98% Cotton, 2% Spandex</li>\n<li>Machine wash up to 30°C/86°F gentle cycle</li>\n<li>Do not bleach</li>\n<li>Iron up to 110°C/230°F</li>\n<li>Do not dry clean</li>\n<li>Do not tumble dry.</li>\n</ul>", "vendor": "Women", "product_type": "TROUSERS", "created_at": "2022-02-04T12:19:40+05:00", "handle": "f0038-208-426", "updated_at": "2022-04-18T09:18:25+05:00", "published_at": "2022-03-07T15:13:44+05:00", "template_suffix": "", "published_scope": "global", "tags": "4fb, Casual, F0038/208/426-SimplifiedSizechart, Jeans, L, M, Mom, Pale Pink, PKR 3090 - PKR 3990, Rcolor | f0038-208-001, Rem-bundle, Ritem | f0041-206-001, Ritem | f0042-212-001, S, SS-22, Summer, W-Jeans-SS-22, women-size-chart, WomenSS-22, XS", "variants": [{"id": 41286711214271, "product_id": 7155381043391, "title": "Pale Pink / 24 / SS-22", "price": "3290.00", "sku": "F0038/208/426-10354618", "position": 1, "compare_at_price": "3290.00", "fulfillment_service": "manual", "inventory_management": "shopify", "option1": "Pale Pink", "option2": "24", "option3": "SS-22", "created_at": "2022-02-04T12:19:41+05:00", "updated_at": "2022-04-18T09:18:25+05:00", "taxable": false, "barcode": "10354618", "grams": 500, "image_id": null, "weight": 0.5, "weight_unit": "kg", "tax_code": "", "requires_shipping": true}, {"id": 41286711247039, "product_id": 7155381043391, "title": "Pale Pink / 26 / SS-22", "price": "3290.00", "sku": "F0038/208/426-10354619", "position": 2, "compare_at_price": "3290.00", "fulfillment_service": "manual", "inventory_management": "shopify", "option1": "Pale Pink", "option2": "26", "option3": "SS-22", "created_at": "2022-02-04T12:19:41+05:00", "updated_at": "2022-03-25T22:52:05+05:00", "taxable": false, "barcode": "10354619", "grams": 500, "image_id": null, "weight": 0.5, "weight_unit": "kg", "tax_code": "", "requires_shipping": true}, {"id": 41286711279807, "product_id": 7155381043391, "title": "Pale Pink / 28 / SS-22", "price": "3290.00", "sku": "F0038/208/426-10354620", "position": 3, "compare_at_price": "3290.00", "fulfillment_service": "manual", "inventory_management": "shopify", "option1": "Pale Pink", "option2": "28", "option3": "SS-22", "created_at": "2022-02-04T12:19:41+05:00", "updated_at": "2022-04-02T11:34:20+05:00", "taxable": false, "barcode": "10354620", "grams": 500, "image_id": null, "weight": 0.5, "weight_unit": "kg", "tax_code": "", "requires_shipping": true}, {"id": 41286711312575, "product_id": 7155381043391, "title": "Pale Pink / 30 / SS-22", "price": "3290.00", "sku": "F0038/208/426-10354621", "position": 4, "compare_at_price": "3290.00", "fulfillment_service": "manual", "inventory_management": "shopify", "option1": "Pale Pink", "option2": "30", "option3": "SS-22", "created_at": "2022-02-04T12:19:41+05:00", "updated_at": "2022-04-12T23:50:15+05:00", "taxable": false, "barcode": "10354621", "grams": 500, "image_id": null, "weight": 0.5, "weight_unit": "kg", "tax_code": "", "requires_shipping": true}, {"id": 41286711345343, "product_id": 7155381043391, "title": "Pale Pink / 32 / SS-22", "price": "3290.00", "sku": "F0038/208/426-10354616", "position": 5, "compare_at_price": "3290.00", "fulfillment_service": "manual", "inventory_management": "shopify", "option1": "Pale Pink", "option2": "32", "option3": "SS-22", "created_at": "2022-02-04T12:19:41+05:00", "updated_at": "2022-02-04T14:26:20+05:00", "taxable": false, "barcode": "10354616", "grams": 500, "image_id": null, "weight": 0.5, "weight_unit": "kg", "tax_code": "", "requires_shipping": true}, {"id": 41286711378111, "product_id": 7155381043391, "title": "Pale Pink / 34 / SS-22", "price": "3290.00", "sku": "F0038/208/426-10354617", "position": 6, "compare_at_price": "3290.00", "fulfillment_service": "manual", "inventory_management": "shopify", "option1": "Pale Pink", "option2": "34", "option3": "SS-22", "created_at": "2022-02-04T12:19:41+05:00", "updated_at": "2022-04-15T14:05:35+05:00", "taxable": false, "barcode": "10354617", "grams": 500, "image_id": null, "weight": 0.5
-06T11:25:43+05:00", "alt": null, "width": 1600, "height": 2000, "src": "https://cdn.shopify.com/s/files/1/2290/7887/products/F0038208426_3_ba16502f-47c7-4782-b571-0fae87d005ce.jpg?v=1649226343", "variant_ids": []}], "image": {"id": 32103290372287, "product_id": 7155381043391, "position": 1, "created_at": "2022-04-06T11:25:39+05:00", "updated_at": "2022-04-06T11:25:43+05:00", "alt": null, "width": 1600, "height": 2000, "src": "https://cdn.shopify.com/s/files/1/2290/7887/products/F0038208426lowers_1_382760a4-ff15-4614-a80e-03e7b07476d3.jpg?v=1649226343", "variant_ids": []}}}

# %%
# !pip install redis
import json
import redis
def load_jsonl(input_path) -> list:
    """
    Read list of objects from a JSON lines file.
    """
    data = []
    with open(input_path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line.rstrip('\n|\r')))
    print('Loaded {} records from {}'.format(len(data), input_path))
    return data

client = redis.Redis(host = '43.251.253.107', port=1500,db=1)
webpage_data = load_jsonl('/content/drive/MyDrive/Cognilium/data1brandspopper.jsonl')
# for d in webpage_data:
for item in webpage_data:
  try:
    client.sadd('allProductTypes',item['product']['product_type'])
  except Exception as e:
    print(e)
# Out:
# ...
#      |████████████████████████████████| 226 kB 5.5 MB/s
# ...
# Loaded 895 records from /content/drive/MyDrive/Cognilium/data1brandspopper.jsonl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-535409e901d6> in <module>()
#      18 for item in webpage_data:
#      19   try:
# ---> 20     client.sadd('allProductTypes',item['product']['product_type'])
#      21   except Exception as e:
#      22     print(e)
#
# /usr/local/lib/python3.7/dist-packages/redis/commands/core.py in sadd(self, name, *values)
#    3095         For more information see https://redis.io/commands/sadd
#    3096         """
# -> 3097         return self.execute_command("SADD", name, *values)
#    3098
#    3099     def scard(self, name: str) -> Union[Awaitable[int], int]:
#
# /usr/local/lib/python3.7/dist-packages/redis/client.py in execute_command(self, *args, **options)
# ...

# %%
{"product": {"id": 6678554902611, "title": "P&B Sleevel
ess Mock Neck Zipper Jacket For Men-Dark Grey & Dark Navy-SP6030", "body_html": 
"<ul>\n<li><strong>Fabric: Fleece</strong></li>\n<li>\n<strong>Best Stitching</
><br>\n</li>\n<li><strong>Export Quality</strong></li>\n<li><strong>Style: Sleeve
less</strong></li>\n<li><strong>Neck: Mock Neck</strong></li>\n</ul>\n<h3><em><st
rong><span style=\"text-decoration: underline;\" data-mce-style=\"text-decoration: 
underline;\"></span></strong></em></h3>\n<h3><em><strong><span style=\"text-decoration
: underline;\" data-mce-style=\"text-decoration: underline;\">Size Chart:</span></strong>
</em></h3>\n<table width=\"100%\">\n<tbody>\n<tr style=\"height: 26.0938px;\" data-mce-st
yle=\"height: 26.0938px;\">\n<td style=\"width: 196px; text-align: center; height: 26.0938px
;\" data-mce-style=\"width: 196px; text-align: center; height: 26.0938px;\"><em><strong>Size<
/strong></em></td>\n<td style=\"width: 213px; text-align: center; height: 26.0938px;\" data-m
ce-style=\"width: 213px; text-align: center; height: 26.0938px;\"><em><strong>Chest</strong></
em></td>\n<td style=\"width: 123px; text-align: center; height: 26.0938px;\" data-mce-style=\"w
    eated_at": "2021-12-29T16:06:00+05:00", "updated_at": "2021-12-29T16:07:05+05:00", "taxable": true, "barcode": "", "grams": 0, "image_i
    d": null, "weight": 0.0, "weight_unit": "g", "inventory_quantity": 4, "old_inventory_quantity": 4, "requires_shipping": true}, {"id": 3
    9618466447443, "product_id": 6678554902611, "title": "XL", "price": "899.00", "sku": "C24xL29", "position": 2, "inventory_policy": "den
    y", "compare_at_price": "2499.00", "fulfillment_service": "manual", "inventory_management": "shopify", "option1": "XL", "option2": null
    , "option3": null, "created_at": "2021-12-29T16:06:00+05:00", "updated_at": "2022-02-13T20:44:50+05:00", "taxable": true, "barcode": "", 
    "grams": 0, "image_id": null, "weight": 0.0, "weight_unit": "g", "inventory_quantity": 0, "old_inventory_quantity": 0, "requires_shippin
    g": true}], "options": [{"id": 8604615901267, "product_id": 6678554902611, "name": "Size", "position": 1, "values": ["M", "XL"]}], 
    "images": [{"id": 29563954626643, "product_id": 6678554902611, "position": 1, "created_at": "2021-12-29T16:06:19+05:00", "updat
    ed_at": "2021-12-29T16:06:21+05:00", "alt": null, "width": 1050, "height": 1400, "src": 
    "https://cdn.shopify.com/s/files/1/0978/2406/products/1117Wx1400H-460529095-black-MODEL.jpg?v=1640775981", 
    "variant_ids": []}, {"id": 29565343629395, "product_id": 6678554902611, "position": 2, "created_at": "2021-1
    2-29T20:01:20+05:00", "updated_at": "2021-12-29T20:01:22+05:00", "alt": null, "width": 3000, "height": 4000, 
    "src": "https://cdn.shopify.com/s/files/1/0978/2406/products/DSC_0698_3fc8b10b-dd8a-4145-8385-e5f3f64b639d.jpg?v=1640790082",
     "variant_ids": []}, {"id": 29565343662163, "product_id": 6678554902611, "position": 3, "created_at": "2021-12-29T20:01:20+0
     5:00", "updated_at": "2021-12-29T20:01:22+05:00", "alt": null, "width": 3000, "height": 4000,
      "src": "https://cdn.shopify.com/s/files/1/0978/2406/products/DSC_0699_b80d2c60-e1e4-4013-ab43-232d312e7165.jpg?v=1640790082", "variant_ids": []}, {"id": 29565343694931, "product_id": 6678554902611, "position": 4, "created_at": "2021-12-29T20:01:20+05:00", "updated_at": "2021-12-29T20:01:23+05:00", "alt": null, "width": 3000, "height": 4000, "src": "https://cdn.shopify.com/s/files/1/0978/2406/products/DSC_0700_bc937e8b-730f-439d-80db-8af59e934663.jpg?v=1640790083", "variant_ids": []}, {"id": 29565343596627, "product_id": 6678554902611, "position": 5, "created_at": "2021-12-29T20:01:20+05:00", "updated_at": "2021-12-29T20:01:22+05:00", "alt": null, "width": 3000, "height": 4000, "src": "https://cdn.shopify.com/s/files/1/0978/2406/products/DSC_0701_e484e58c-ff73-469b-a807-e4dc62f6fb32.jpg?v=1640790082", "variant_ids": []}], "image": {"id": 29563954626643, "product_id": 6678554902611, "position": 1, "created_at": "2021-12-29T16:06:19+05:00", "updated_at": "2021-12-29T16:06:21+05:00", "alt": null, "width": 1050, "height": 1400, "src": "https://cdn.shopify.com/s/files/1/0978/2406/products/1117Wx1400H-460529095-black-MODEL.jpg?v=1640775981", "variant_ids": []}}}
